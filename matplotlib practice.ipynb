# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (12, 6))

x = np.linspace(-100, 100, 100)
y = np.cos(x)
z = np.sin(x)

plt.subplot(121)
plt.scatter(x,y, color = 'firebrick')

plt.subplot(122)
plt.scatter(x, z);

# %%
import numpy as np
from matplotlib import pyplot as plt

#plt.rcParams["figure.figsize"] = [7.50, 3.50]
#plt.rcParams["figure.autolayout"] = True

x = np.linspace(-2, 2, 1000)
y1 = np.sqrt(1 - (abs(x) - 1) ** 2)
y2 = -3 * np.sqrt(1 - (abs(x) / 2) ** 0.5)

ax = plt.axes()
ax.set_facecolor('lightyellow')
plt.fill_between(x, y1, color='limegreen')
plt.fill_between(x, y2, color='limegreen')

#plt.scatter(x, y1, color = 'red')
#plt.scatter(x, y2, color = 'red')

#plt.text(0, -1.0, 'Heart', fontsize=24, color='black',horizontalalignment='center')

plt.show()
